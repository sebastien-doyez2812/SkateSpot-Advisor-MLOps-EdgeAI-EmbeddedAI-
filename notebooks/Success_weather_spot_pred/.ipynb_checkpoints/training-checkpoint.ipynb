# %%
import tensorflow as tf
import boto3, os
from tensorflow import keras
from tensorflow.keras.layers import Input, Embedding, Concatenate, Dense
import pandas as pd
from io import StringIO
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2025-12-03 01:31:03.948038: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-03 01:31:03.948849: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-03 01:31:04.054679: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-03 01:31:05.561408: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-03 01:31:05.561945: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# ## Training Parameters:

# %%
EPOCHS = 200 #150
BATCHSIZE = 32
LR0 = 1e-4
ALPHA = 1e-2
TRAIN_PERCENTAGE = 0.8

# %% [markdown]
# ## Generator:

# %% [markdown]
# Get access to the S3 bucket:

# %%
s3 = boto3.client(
    "s3",
    endpoint_url=os.getenv("S3_ENDPOINT"),
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    region_name="us-east-1"
)

# %%
BUCKET_NAME = "skatedata"   
FILE_KEY = "clean_skatepark_dataset.csv"  

obj = s3.get_object(Bucket=BUCKET_NAME, Key=FILE_KEY)
df = pd.read_csv(StringIO(obj['Body'].read().decode('utf-8')))

print(df.head())
# Out:
#      spot_name  index spot  weather  satisfaction
# 0     Ahuntsic           0        0             0
# 1     VanHorne           1        0             0
# 2       Verdun           2        0             0
# 3      Lasalle           3        0             0
# 4  Préfontaine           4        0             0

# %%
import numpy as np
import random
from tensorflow.keras.utils import Sequence

class SkateSpotGenerator(Sequence):
    def __init__(self, df, batchsize=32):
        self.df = df
        self.df_size = df.shape[0]
        self.n_skateparks = df["index spot"].nunique()
        self.batchsize = batchsize

        # Indices des groupes complets seulement
        self.indexes = list(range(0, self.df_size - self.n_skateparks + 1, self.n_skateparks))
        self.on_epoch_end()  # shuffle initial

    def __len__(self):
        return int(np.ceil(len(self.indexes) / self.batchsize))

    def __getitem__(self, idx):
        batch_start = idx * self.batchsize
        batch_end = batch_start + self.batchsize
        batch_indices = self.indexes[batch_start:batch_end]

        id_batch = []
        weather_batch = []
        temp_batch = []
        traffic_batch = []
        satisfaction_batch = []

        for current_idx in batch_indices:
            row = self.df.iloc[current_idx]
            id_batch.append(row["index spot"])
            weather_batch.append(row["weather"])
            #temp.append(row["temperature"])
            #traffic.append(row["traffic_time"])
            satisfaction_batch.append(row["satisfaction"])

        return (
            (
                np.array(id_batch),
                np.array(weather_batch),
                #np.array(temp_batch),
                #np.array(traffic_batch)
            ),
            np.array(satisfaction_batch)
        )

    def on_epoch_end(self):
        random.shuffle(self.indexes)

# %%
df_train = df.sample(frac=TRAIN_PERCENTAGE, random_state=42)  
df_val   = df.drop(df_train.index)             

step = len(df_train)/BATCHSIZE
LR = tf.keras.optimizers.schedules.CosineDecay(LR0, step, alpha= ALPHA)
train_generator = SkateSpotGenerator(df = df_train, batchsize = BATCHSIZE)
val_generator   = SkateSpotGenerator(df = df_val, batchsize = BATCHSIZE)

# %%
# Architecture:
def DNN():
    input_id_skatepark = Input(shape = (1,), name= 'id_skateparks')
    input_weather  = Input(shape=(1,), name='weather_input')
    #input_temp     = Input(shape=(15,), name='weather_temp')
    #intput_traffic = Input(shape=(15,), name='weather_traffic')

    # Embedding to create vectors for index:
    emb_skatepark = Embedding(input_dim=15 + 1, output_dim=5)(input_id_skatepark)
    emb_skatepark = tf.keras.layers.Flatten()(emb_skatepark)
    
    emb_weather = Embedding(input_dim=4 + 1, output_dim=2)(input_weather)
    emb_weather = tf.keras.layers.Flatten()(emb_weather)

    concat_features = Concatenate()([
        emb_skatepark,
        emb_weather,
        #input_temp,
        #intput_traffic
    ])


    x = Dense(64, activation='relu')(concat_features)
    x = Dense(32, activation='relu')(x)

    output = Dense(1, activation = "sigmoid", name='preference_score')(x)

    model = keras.Model(
        inputs = [input_id_skatepark, input_weather],#, input_temp, intput_traffic ],
        outputs = output
    )
    optimizer_adam = tf.keras.optimizers.Adam(learning_rate=LR) 
    model.compile(
        optimizer=optimizer_adam,
        loss='binary_crossentropy',
        metrics=['mae']
    )
    model.summary()    
    return model

model = DNN()
# Out:
# 2025-12-03 01:31:06.947657: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ id_skateparks       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ weather_input       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 1, 5)      │         80 │ id_skateparks[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 1, 2)      │         10 │ weather_input[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 5)         │          0 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 2)         │          0 │ embedding_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 7)         │          0 │ flatten[0][0],    │
# │ (Concatenate)       │                   │            │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │        512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │      2,080 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ preference_score    │ (None, 1)         │         33 │ dense_1[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,715 (10.61 KB)
#  Trainable params: 2,715 (10.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Idea:**
#
# inputs:
#
#
# _ list np.array of index for the weather
#
#         0 = snow or rain
#         1 = heavy cloudy/ Windy
#         2= cloudy
#         3 = blue sky
#
# _ list np.array of temperature in °C
#
# _ Traffic time in minutes

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    verbose=1
)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6859 - mae: 0.4963 - val_loss: 0.6786 - val_mae: 0.4926
# Epoch 2/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6692 - mae: 0.4875 - val_loss: 0.6589 - val_mae: 0.4819
# Epoch 3/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6471 - mae: 0.4751 - val_loss: 0.6374 - val_mae: 0.4692
# Epoch 4/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6239 - mae: 0.4606 - val_loss: 0.6133 - val_mae: 0.4536
# Epoch 5/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6015 - mae: 0.4458 - val_loss: 0.5949 - val_mae: 0.4402
# Epoch 6/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5829 - mae: 0.4313 - val_loss: 0.5781 - val_mae: 0.4266
# Epoch 7/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5681 - mae: 0.4188 - val_loss: 0.5656 - val_mae: 0.4152
# Epoch 8/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5567 - mae: 0.4082 - val_loss: 0.5575 - val_mae: 0.4069
# Epoch 9/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5488 - mae: 0.4003 - val_loss: 0.5513 - val_mae: 0.4001
# Epoch 10/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5432 - mae: 0.3945 - val_loss: 0.5476 - val_mae: 0.3958
# Epoch 11/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5397 - mae: 0.3902 - val_loss: 0.5450 - val_mae: 0.3925
# Epoch 12/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5372 - mae: 0.3879 - val_loss: 0.5436 - val_mae: 0.3908
# Epoch 13/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5359 - mae: 0.3864 - val_loss: 0.5428 - val_mae: 0.3897
# Epoch 14/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5353 - mae: 0.3856 - val_loss: 0.5425 - val_mae: 0.3892
# Epoch 15/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5215 - mae: 0.3675 - val_loss: 0.5316 - val_mae: 0.3724
# Epoch 179/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5215 - mae: 0.3674 - val_loss: 0.5315 - val_mae: 0.3723
# Epoch 180/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5214 - mae: 0.3673 - val_loss: 0.5315 - val_mae: 0.3722
# Epoch 181/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5213 - mae: 0.3672 - val_loss: 0.5314 - val_mae: 0.3721
# Epoch 182/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5213 - mae: 0.3671 - val_loss: 0.5314 - val_mae: 0.3720
# Epoch 183/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5212 - mae: 0.3670 - val_loss: 0.5313 - val_mae: 0.3719
# Epoch 184/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5211 - mae: 0.3669 - val_loss: 0.5313 - val_mae: 0.3718
# Epoch 185/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5211 - mae: 0.3668 - val_loss: 0.5312 - val_mae: 0.3718
# Epoch 186/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5210 - mae: 0.3667 - val_loss: 0.5312 - val_mae: 0.3717
# Epoch 187/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5209 - mae: 0.3666 - val_loss: 0.5311 - val_mae: 0.3716
# Epoch 188/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5209 - mae: 0.3665 - val_loss: 0.5311 - val_mae: 0.3715
# Epoch 189/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5208 - mae: 0.3664 - val_loss: 0.5310 - val_mae: 0.3714
# Epoch 190/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5207 - mae: 0.3664 - val_loss: 0.5310 - val_mae: 0.3713
# Epoch 191/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5207 - mae: 0.3663 - val_loss: 0.5309 - val_mae: 0.3712
# Epoch 192/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5206 - mae: 0.3662 - val_loss: 0.5309 - val_mae: 0.3711
# Epoch 193/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5206 - mae: 0.3661 - val_loss: 0.5309 - val_mae: 0.3711
# Epoch 194/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5205 - mae: 0.3660 - val_loss: 0.5308 - val_mae: 0.3710
# Epoch 195/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5204 - mae: 0.3659 - val_loss: 0.5308 - val_mae: 0.3709
# Epoch 196/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5204 - mae: 0.3658 - val_loss: 0.5307 - val_mae: 0.3708
# Epoch 197/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5203 - mae: 0.3657 - val_loss: 0.5307 - val_mae: 0.3707
# Epoch 198/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5202 - mae: 0.3656 - val_loss: 0.5306 - val_mae: 0.3706
# Epoch 199/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5202 - mae: 0.3655 - val_loss: 0.5306 - val_mae: 0.3706
# Epoch 200/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5201 - mae: 0.3655 - val_loss: 0.5306 - val_mae: 0.3705

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

mae = history.history.get('mae')
val_mae = history.history.get('val_mae')

epochs = range(1, EPOCHS + 1)

plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
plt.plot(epochs, loss, 'bo-', label = "Training loss")
plt.plot(epochs, val_loss, 'ro-', label = "Val loss")

plt.title("Loss evolution")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, mae, 'bo-', label='Training mae')
plt.plot(epochs, val_mae, 'ro-', label="Validation mae")
plt.title( "mae evolution")
plt.xlabel('Epochs')
plt.ylabel("mae")
plt.legend()
plt.show()

# %% [markdown]
# ## Testing:

# %%
skateparks_list = [
    "Ahuntsic"         , # 0
    "VanHorne"         , # 1
    "Verdun"           , # 2
    "Lasalle"          , # 3
    "Préfontaine"      , # 4
    "Boucherville"     , # 5
    "Taz"              , # 6
    "Spin"             , # 7
    "Saint Jérome"     , # 8
    "Saint Sauveur"    , # 9
    "Assomption"       , # 10
    "Benny"            , # 11
    "Dorval"           , # 12
    "Magog"            , # 13
    "Berthierville"      # 14
]

# Weather: 
# Rain or Snow  = 0
# Clouds + Wind = 1
# Clouds        = 2
# Blue sky      = 3

weather_dict = {
    0: "Rain or Snow",
    1: "Windy or heavily cloudy",
    2: "cloudy",
    3: "Blue sky"
}

for idx_weather, weather_name in weather_dict.items():
    print("\n\n\n=== Weather:", weather_name, "===")
    for idx_skatespot, skatespot in enumerate(skateparks_list):

        result = model.predict([
            np.array([idx_skatespot]),   # index du skatepark
            np.array([idx_weather])    # weather
        ])
        print(f"Result for {skatespot} = {result[0][0] * 100} %")
# Out:
# === Weather: Rain or Snow ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Result for Ahuntsic = 22.369163513183594 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for VanHorne = 22.489259719848633 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Verdun = 21.977834701538086 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Result for Lasalle = 25.391971588134766 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Result for Préfontaine = 26.80323028564453 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Boucherville = 29.52163314819336 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Result for Taz = 27.84150505065918 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Result for Spin = 27.564712524414062 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Saint Jérome = 24.886877059936523 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Saint Sauveur = 24.59368324279785 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Assomption = 29.5440616607666 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Benny = 27.297378540039062 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Result for Dorval = 26.643535614013672 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Result for Magog = 28.001806259155273 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Result for Berthierville = 24.75213623046875 %
#
#
#
# === Weather: Windy or heavily cloudy ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Result for Ahuntsic = 23.418460845947266 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Result for VanHorne = 23.622468948364258 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Verdun = 22.996078491210938 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Lasalle = 26.465988159179688 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Result for Préfontaine = 27.911291122436523 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Result for Boucherville = 30.930042266845703 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Result for Taz = 28.816619873046875 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Spin = 28.399137496948242 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Saint Jérome = 25.992294311523438 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Saint Sauveur = 25.709257125854492 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Result for Assomption = 30.543405532836914 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Benny = 28.399961471557617 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Dorval = 27.622314453125 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Magog = 29.080581665039062 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Berthierville = 25.72689437866211 %
#
#
#
# === Weather: cloudy ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Ahuntsic = 24.402158737182617 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for VanHorne = 24.58877944946289 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Verdun = 23.93406867980957 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Lasalle = 27.410465240478516 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Préfontaine = 28.7996883392334 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Boucherville = 31.865331649780273 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Taz = 29.769506454467773 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Spin = 29.283178329467773 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Saint Jérome = 27.039688110351562 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Saint Sauveur = 26.75066375732422 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Assomption = 31.485822677612305 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Result for Benny = 29.362499237060547 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Result for Dorval = 28.602657318115234 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Result for Magog = 30.102935791015625 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Berthierville = 26.674407958984375 %
#
#
#
# === Weather: Blue sky ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Ahuntsic = 24.143917083740234 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for VanHorne = 24.274995803833008 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Verdun = 23.705081939697266 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Lasalle = 27.107107162475586 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Préfontaine = 28.372726440429688 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Result for Boucherville = 31.282421112060547 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Taz = 29.481645584106445 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Spin = 29.149070739746094 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Result for Saint Jérome = 26.739913940429688 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Result for Saint Sauveur = 26.461681365966797 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Assomption = 31.1888427734375 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Benny = 29.059001922607422 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Result for Dorval = 28.350574493408203 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Result for Magog = 29.807758331298828 %
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result for Berthierville = 26.420848846435547 %
